# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("IRIS.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.mean()
# Out:
# C:\Users\Laksh\AppData\Local\Temp\ipykernel_11112\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Laksh\AppData\Local\Temp\ipykernel_11112\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
df.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# 145              NaN
# 146              NaN
# 147              NaN
# 148              NaN
# 149              NaN
#
# [150 rows x 6 columns]

# %%
df.std()
# Out:
# C:\Users\Laksh\AppData\Local\Temp\ipykernel_11112\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %% [markdown]
# df.min()

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.var()
# Out:
# C:\Users\Laksh\AppData\Local\Temp\ipykernel_11112\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Id               1887.500000
# SepalLengthCm       0.685694
# SepalWidthCm        0.188004
# PetalLengthCm       3.113179
# PetalWidthCm        0.582414
# dtype: float64

# %%
plt.hist(df['SepalLengthCm'])
plt.show()

# %%
plt.figure(figsize = (10,7))
df.boxplot()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,8))
axes[0,0].set_title("Distribution of Sepal Length")
axes[0,0].hist(df["SepalLengthCm"])
axes[0,1].set_title("Distribution of Sepal Width")
axes[0,1].hist(df["SepalWidthCm"])
axes[1,0].set_title("Distribution of Petal Length")
axes[1,0].hist(df["PetalLengthCm"])
axes[1,1].set_title("Distribution of Petal Width")
axes[1,1].hist(df["PetalWidthCm"])
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
axes[0,0].set_title("Distribution of Sepal Length")
sns.boxplot(y="SepalLengthCm", x="Species", data=df, orient='v', ax=axes[0,0])
axes[0,1].set_title("Distribution of Sepal Length")
sns.boxplot(y="SepalWidthCm", x="Species", data=df, orient='v', ax=axes[0,1])
axes[1,0].set_title("Distribution of Sepal Length")
sns.boxplot(y="PetalLengthCm", x="Species", data=df, orient='v', ax=axes[1,0])
axes[1,1].set_title("Distribution of Sepal Length")
sns.boxplot(y="PetalLengthCm", x="Species", data=df, orient='v', ax=axes[1,1])
plt.show()
