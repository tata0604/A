# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Student_Performance1.csv")
df
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 0   Female        84.0             77             83               89
# 1     male        81.0             73             64               93
# 2   female        84.0             79             75               97
# 3     male        82.0             78             88               91
# 4     male        85.0             78             80               97
# 5     male        81.0             72             78               75
# 6   female         NaN             70             65               84
# 7   female        80.0             79             70               83
# 8   female        84.0             72             74               73
# 9     male        85.0             76             61               78
# 10    male        80.0             74             68               90
# 11  female         NaN             74             71               97
# 12    male         NaN             75             87               92
# 13    male        81.0             76             72               78
# 14  female        84.0             75             71               72
# 15    male         NaN             73             66               92
# 16    male        83.0             70             76               86
# 17    male        83.0             77             63               70
# 18  female         NaN             70             81               74
# 19  female        82.0             77             66               82
# 20  female        83.0             70             62               98
# 21    male         0.0             80             64               89
# 22    male        81.0             71             82               96
# 23    male         NaN             74             60               99
# 24  female        85.0             73             64               84
# 25    male        80.0             73             67               96
# 26  female        80.0             70             88               78
# 27  female        83.0             79             82               90
# 28    male        84.0             72             66               90
# 29  female        80.0             75             65               98
#
#     club_join_date  placement_offer_count
# 0             2020  placement_offer_count
# 1             2020  placement_offer_count
# 2             2019  placement_offer_count
# 3             2020  placement_offer_count
# 4             2018  placement_offer_count
# 5             2019  placement_offer_count
# 6             2019  placement_offer_count
# 7             2018  placement_offer_count
# 8             2019  placement_offer_count
# 9             2019  placement_offer_count
# 10            2021  placement_offer_count
# 11            2020  placement_offer_count
# 12            2018  placement_offer_count
# 13            2021  placement_offer_count
# 14            2021  placement_offer_count
# 15            2018  placement_offer_count
# 16            2020  placement_offer_count
# 17            2019  placement_offer_count
# 18            2018  placement_offer_count
# 19            2018  placement_offer_count
# 20            2021  placement_offer_count
# 21            2020  placement_offer_count
# 22            2018  placement_offer_count
# 23            2018  placement_offer_count
# 24            2020  placement_offer_count
# 25            2019  placement_offer_count
# 26            2021  placement_offer_count
# 27            2021  placement_offer_count
# 28            2018  placement_offer_count
# 29            2019  placement_offer_count

# %%
df.isnull()
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False            False
# 5    False       False          False          False            False
# 6    False        True          False          False            False
# 7    False       False          False          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False        True          False          False            False
# 12   False        True          False          False            False
# 13   False       False          False          False            False
# 14   False       False          False          False            False
# 15   False        True          False          False            False
# 16   False       False          False          False            False
# 17   False       False          False          False            False
# 18   False        True          False          False            False
# 19   False       False          False          False            False
# 20   False       False          False          False            False
# 21   False       False          False          False            False
# 22   False       False          False          False            False
# 23   False        True          False          False            False
# 24   False       False          False          False            False
# 25   False       False          False          False            False
# 26   False       False          False          False            False
# 27   False       False          False          False            False
# 28   False       False          False          False            False
# 29   False       False          False          False            False
#
#     club_join_date  placement_offer_count
# 0            False                  False
# 1            False                  False
# 2            False                  False
# 3            False                  False
# 4            False                  False
# 5            False                  False
# 6            False                  False
# 7            False                  False
# 8            False                  False
# 9            False                  False
# 10           False                  False
# 11           False                  False
# 12           False                  False
# 13           False                  False
# 14           False                  False
# 15           False                  False
# 16           False                  False
# 17           False                  False
# 18           False                  False
# 19           False                  False
# 20           False                  False
# 21           False                  False
# 22           False                  False
# 23           False                  False
# 24           False                  False
# 25           False                  False
# 26           False                  False
# 27           False                  False
# 28           False                  False
# 29           False                  False

# %%
series = pd.isnull(df["math_score"])
df[series]
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 6   female         NaN             70             65               84
# 11  female         NaN             74             71               97
# 12    male         NaN             75             87               92
# 15    male         NaN             73             66               92
# 18  female         NaN             70             81               74
# 23    male         NaN             74             60               99
#
#     club_join_date  placement_offer_count
# 6             2019  placement_offer_count
# 11            2020  placement_offer_count
# 12            2018  placement_offer_count
# 15            2018  placement_offer_count
# 18            2018  placement_offer_count
# 23            2018  placement_offer_count

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
newdf=df
df
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 0        0        84.0             77             83               89
# 1        2        81.0             73             64               93
# 2        1        84.0             79             75               97
# 3        2        82.0             78             88               91
# 4        2        85.0             78             80               97
# 5        2        81.0             72             78               75
# 6        1         NaN             70             65               84
# 7        1        80.0             79             70               83
# 8        1        84.0             72             74               73
# 9        2        85.0             76             61               78
# 10       2        80.0             74             68               90
# 11       1         NaN             74             71               97
# 12       2         NaN             75             87               92
# 13       2        81.0             76             72               78
# 14       1        84.0             75             71               72
# 15       2         NaN             73             66               92
# 16       2        83.0             70             76               86
# 17       2        83.0             77             63               70
# 18       1         NaN             70             81               74
# 19       1        82.0             77             66               82
# 20       1        83.0             70             62               98
# 21       2         0.0             80             64               89
# 22       2        81.0             71             82               96
# 23       2         NaN             74             60               99
# 24       1        85.0             73             64               84
# 25       2        80.0             73             67               96
# 26       1        80.0             70             88               78
# 27       1        83.0             79             82               90
# 28       2        84.0             72             66               90
# 29       1        80.0             75             65               98
#
#     club_join_date  placement_offer_count
# 0             2020  placement_offer_count
# 1             2020  placement_offer_count
# 2             2019  placement_offer_count
# 3             2020  placement_offer_count
# 4             2018  placement_offer_count
# 5             2019  placement_offer_count
# 6             2019  placement_offer_count
# 7             2018  placement_offer_count
# 8             2019  placement_offer_count
# 9             2019  placement_offer_count
# 10            2021  placement_offer_count
# 11            2020  placement_offer_count
# 12            2018  placement_offer_count
# 13            2021  placement_offer_count
# 14            2021  placement_offer_count
# 15            2018  placement_offer_count
# 16            2020  placement_offer_count
# 17            2019  placement_offer_count
# 18            2018  placement_offer_count
# 19            2018  placement_offer_count
# 20            2021  placement_offer_count
# 21            2020  placement_offer_count
# 22            2018  placement_offer_count
# 23            2018  placement_offer_count
# 24            2020  placement_offer_count
# 25            2019  placement_offer_count
# 26            2021  placement_offer_count
# 27            2021  placement_offer_count
# 28            2018  placement_offer_count
# 29            2019  placement_offer_count

# %%
missing_values = ["Na", "na"]
df = pd.read_csv("Student_Performance.csv", na_values =
missing_values)
df
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 0   Female          84             77             83               89
# 1     male          81             73             64               93
# 2   female          84             79             75               97
# 3     male          82             78             88               91
# 4     male          85             78             80               97
# 5     male          81             72             78               75
# 6   female          85             70             65               84
# 7   female          80             79             70               83
# 8   female          84             72             74               73
# 9     male          85             76             61               78
# 10    male          80             74             68               90
# 11  female          82             74             71               97
# 12    male          84             75             87               92
# 13    male          81             76             72               78
# 14  female          84             75             71               72
# 15    male          80             73             66               92
# 16    male          83             70             76               86
# 17    male          83             77             63               70
# 18  female          80             70             81               74
# 19  female          82             77             66               82
# 20  female          83             70             62               98
# 21    male          83             80             64               89
# 22    male          81             71             82               96
# 23    male          84             74             60               99
# 24  female          85             73             64               84
# 25    male          80             73             67               96
# 26  female          80             70             88               78
# 27  female          83             79             82               90
# 28    male          84             72             66               90
# 29  female          80             75             65               98
#
#     club_join_date  placement_offer_count
# 0             2020  placement_offer_count
# 1             2020  placement_offer_count
# 2             2019  placement_offer_count
# 3             2020  placement_offer_count
# 4             2018  placement_offer_count
# 5             2019  placement_offer_count
# 6             2019  placement_offer_count
# 7             2018  placement_offer_count
# 8             2019  placement_offer_count
# 9             2019  placement_offer_count
# 10            2021  placement_offer_count
# 11            2020  placement_offer_count
# 12            2018  placement_offer_count
# 13            2021  placement_offer_count
# 14            2021  placement_offer_count
# 15            2018  placement_offer_count
# 16            2020  placement_offer_count
# 17            2019  placement_offer_count
# 18            2018  placement_offer_count
# 19            2018  placement_offer_count
# 20            2021  placement_offer_count
# 21            2020  placement_offer_count
# 22            2018  placement_offer_count
# 23            2018  placement_offer_count
# 24            2020  placement_offer_count
# 25            2019  placement_offer_count
# 26            2021  placement_offer_count
# 27            2021  placement_offer_count
# 28            2018  placement_offer_count
# 29            2019  placement_offer_count

# %%
ndf=df
ndf.fillna(0)
# Out:
#     Gender  math_score  reading_score  writing_score  placement_score  \
# 0        0          84             77             83               89
# 1        2          81             73             64               93
# 2        1          84             79             75               97
# 3        2          82             78             88               91
# 4        2          85             78             80               97
# 5        2          81             72             78               75
# 6        1           0             70             65               84
# 7        1          80             79             70               83
# 8        1          84             72             74               73
# 9        2          85             76             61               78
# 10       2          80             74             68               90
# 11       1           0             74             71               97
# 12       2           0             75             87               92
# 13       2          81             76             72               78
# 14       1          84             75             71               72
# 15       2           0             73             66               92
# 16       2          83             70             76               86
# 17       2          83             77             63               70
# 18       1           0             70             81               74
# 19       1          82             77             66               82
# 20       1          83             70             62               98
# 21       2           0             80             64               89
# 22       2          81             71             82               96
# 23       2           0             74             60               99
# 24       1          85             73             64               84
# 25       2          80             73             67               96
# 26       1          80             70             88               78
# 27       1          83             79             82               90
# 28       2          84             72             66               90
# 29       1          80             75             65               98
#
#     club_join_date  placement_offer_count
# 0             2020  placement_offer_count
# 1             2020  placement_offer_count
# 2             2019  placement_offer_count
# 3             2020  placement_offer_count
# 4             2018  placement_offer_count
# 5             2019  placement_offer_count
# 6             2019  placement_offer_count
# 7             2018  placement_offer_count
# 8             2019  placement_offer_count
# 9             2019  placement_offer_count
# 10            2021  placement_offer_count
# 11            2020  placement_offer_count
# 12            2018  placement_offer_count
# 13            2021  placement_offer_count
# 14            2021  placement_offer_count
# 15            2018  placement_offer_count
# 16            2020  placement_offer_count
# 17            2019  placement_offer_count
# 18            2018  placement_offer_count
# 19            2018  placement_offer_count
# 20            2021  placement_offer_count
# 21            2020  placement_offer_count
# 22            2018  placement_offer_count
# 23            2018  placement_offer_count
# 24            2020  placement_offer_count
# 25            2019  placement_offer_count
# 26            2021  placement_offer_count
# 27            2021  placement_offer_count
# 28            2018  placement_offer_count
# 29            2019  placement_offer_count

# %%
col = ['math_score', 'reading_score' , 'writing_score','placement_score']
df.boxplot(col)
# Out:
# <Axes: >
